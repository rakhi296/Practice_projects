# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# load the data
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # Statistical Summary

# %%
# number of rows and column
df.shape
# Out:
# (158, 12)

# %%
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# checking null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no null values, it means data is clean

# %%
# getting some statistical measurement
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # We can see that some countries have min values are 0.

# %% [markdown]
# # Lets try to find countries at bottom in respective category

# %%
df.loc[df['Economy (GDP per Capita)'] == 0.0]
# Out:
#               Country              Region  Happiness Rank  Happiness Score  \
# 119  Congo (Kinshasa)  Sub-Saharan Africa             120            4.517
#
#      Standard Error  Economy (GDP per Capita)  Family  \
# 119          0.0368                       0.0  1.0012
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 119                   0.09806  0.22605                        0.07625
#
#      Generosity  Dystopia Residual
# 119     0.24834            2.86712

# %%
df.loc[df['Family']==0.0]
# Out:
#                       Country              Region  Happiness Rank  \
# 147  Central African Republic  Sub-Saharan Africa             148
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)  Family  \
# 147            3.678         0.06112                    0.0785     0.0
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 147                   0.06699  0.48879                        0.08289
#
#      Generosity  Dystopia Residual
# 147     0.23835             2.7223

# %%
df.loc[df['Health (Life Expectancy)'] ==0.0]
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 122  Sierra Leone  Sub-Saharan Africa             123            4.507
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 122         0.07068                   0.33024  0.95571
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 122                       0.0   0.4084                        0.08786
#
#      Generosity  Dystopia Residual
# 122     0.21488            2.51009

# %%
df.loc[df['Freedom']==0.0]
# Out:
#     Country                           Region  Happiness Rank  Happiness Score  \
# 111    Iraq  Middle East and Northern Africa             112            4.677
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 111         0.05232                   0.98549  0.81889
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 111                   0.60237      0.0                        0.13788
#
#      Generosity  Dystopia Residual
# 111     0.17922            1.95335

# %%
df.loc[df['Trust (Government Corruption)']==0.0]
# Out:
#       Country             Region  Happiness Rank  Happiness Score  \
# 73  Indonesia  Southeastern Asia              74            5.399
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 73         0.02596                   0.82827  1.08708
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 73                   0.63793  0.46611                            0.0
#
#     Generosity  Dystopia Residual
# 73     0.51535            1.86399

# %% [markdown]
# # Minimum Performance Category Wise
# 1. Economy (GDP per Capita) - Congo(Kinshasa)
# 2. Family - Central African Republic
# 3. Health(Life Expectancy) - Sierra Leone
# 4. Freedom - Iraq
# 5. Trust(Government Corruption) - Indonesia

# %%
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (15,6)
happi_score = df['Happiness Score']
gdp = df['Economy (GDP per Capita)']
sns.scatterplot(x=happi_score, y=gdp, hue=df.Region, s=150);
plt.legend(loc='upper left')
plt.title('Scatter plot of Happiness vs GDP')
plt.xlabel('Happiness Score', fontsize='15')
plt.ylabel('GDP per Capita', fontsize='15')
plt.show()

# %%
gdp_region=df.groupby('Region')['Economy (GDP per Capita)'].sum()
gdp_region
# Out:
# Region
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: Economy (GDP per Capita), dtype: float64

# %%
# creating pie plot
gdp_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# total number of countries in each region
total_countries = df.groupby('Region')[['Country']].count()
print(total_countries)
# Out:
#                                  Country
# Region
# Australia and New Zealand              2
# Central and Eastern Europe            29
# Eastern Asia                           6
# Latin America and Caribbean           22
# Middle East and Northern Africa       20
# North America                          2
# Southeastern Asia                      9
# Southern Asia                          7
# Sub-Saharan Africa                    40
# Western Europe                        21

# %% [markdown]
# # Making new dataframe considering Numerical datatypes for further investigation

# %%
happiness_df = df[df.columns[3:]]
happiness_df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# # Skewness detection using distplot and skew()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Happiness Score'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Standard Error'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Economy (GDP per Capita)'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Family'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Health (Life Expectancy)'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Freedom'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Trust (Government Corruption)'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Generosity'], color='blue')
plt.show()

# %%
plt.figure(figsize=(3,4))
sns.distplot(happiness_df['Dystopia Residual'], color='blue')
plt.show()

# %%
happiness_df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# We can see that standard Error, Trust, Generosity are right skewed distribution. As we know Log transform is useful only if the distribution of the variable is right-skewed.A log transformation in a left-skewed distribution will tend to make it even more left skew. Family variable has left skewed distribution.

# %% [markdown]
# # Investingating Correlation between features

# %%
happiness_df.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
corr_=happiness_df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr_,annot= True, cmap='rocket')
# Out:
# <Axes: >

# %% [markdown]
# # Visualization of Corruption in Regions

# %%
# corruption in regions
corruption = df.groupby('Region')[['Trust (Government Corruption)']].mean()
corruption
# Out:
#                                  Trust (Government Corruption)
# Region
# Australia and New Zealand                             0.392795
# Central and Eastern Europe                            0.086674
# Eastern Asia                                          0.127695
# Latin America and Caribbean                           0.117172
# Middle East and Northern Africa                       0.181702
# North America                                         0.244235
# Southeastern Asia                                     0.151276
# Southern Asia                                         0.102536
# Sub-Saharan Africa                                    0.123878
# Western Europe                                        0.231463

# %%
plt.rcParams['figure.figsize'] = (10,8)
region = df['Region']
corruption_ = df['Trust (Government Corruption)']
sns.barplot(x=region, y=corruption_)
plt.title('Perception of Corruption in various Region', fontsize='12')
plt.xlabel('Region', fontsize='12')
plt.ylabel('Corruption Index', fontsize='12')
plt.xticks(rotation=30, ha='right')
plt.show()

# %% [markdown]
# It shows that Austrailia and New Zealand has the highest perception of corruption, and Central and Eastern Europe has the least perception of corruption.

# %% [markdown]
# # Top 10 Happiest Countries Life Expectancy and 10 Least Happy Countries Life Expectancy

# %%
# top 10 happiest countries based on life expectancy
top_10=df.sort_values(by='Health (Life Expectancy)', ascending=False).head(10)
top_10
# Out:
#         Country                     Region  Happiness Rank  Happiness Score  \
# 23    Singapore          Southeastern Asia              24            6.798
# 71    Hong Kong               Eastern Asia              72            5.474
# 45        Japan               Eastern Asia              46            5.987
# 46  South Korea               Eastern Asia              47            5.984
# 35        Spain             Western Europe              36            6.329
# 49        Italy             Western Europe              50            5.948
# 1       Iceland             Western Europe               2            7.561
# 28       France             Western Europe              29            6.575
# 0   Switzerland             Western Europe               1            7.587
# 9     Australia  Australia and New Zealand              10            7.284
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 23         0.03780                   1.52186  1.02000
# ...

# %% [markdown]
# We can see that Singapore is Top on the chart with Heatlh(Life Expectancy) of 1.02525. We can see that 5 countries out of 10 are from Western Europe.

# %%
# 10 least happy countries based on life expectancy
Un_h=df.sort_values(by='Health (Life Expectancy)', ascending=True).head(10)
Un_h
# Out:
#                       Country              Region  Happiness Rank  \
# 122              Sierra Leone  Sub-Saharan Africa             123
# 127                  Botswana  Sub-Saharan Africa             128
# 147  Central African Republic  Sub-Saharan Africa             148
# 100                 Swaziland  Sub-Saharan Africa             101
# 96                    Lesotho  Sub-Saharan Africa              97
# 93                 Mozambique  Sub-Saharan Africa              94
# 119          Congo (Kinshasa)  Sub-Saharan Africa             120
# 148                      Chad  Sub-Saharan Africa             149
# 150               Ivory Coast  Sub-Saharan Africa             151
# 77                    Nigeria  Sub-Saharan Africa              78
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 122            4.507         0.07068                   0.33024  0.95571
# 127            4.332         0.04934                   0.99355  1.10464
# ...

# %% [markdown]
# We can see that Sierra Leone is the unhappiest country with Health(Life Expectancy) of 0.00000. We can see that 10 out of 10 countries are from Sub-Saharan Africa.

# %%
plt.rcParams['figure.figsize'] = (10,6)
hap_s = df['Happiness Score']
sns.scatterplot(x=df.Freedom, y=hap_s, hue=df.Region, s=100)
plt.legend(loc='upper left', fontsize='8')
plt.xlabel('Freedom')
plt.ylabel('Happiness Score')
plt.show()

# %%
country = df.sort_values(by='Trust (Government Corruption)').head(10)
plt.rcParams['figure.figsize'] = (10,5)
plt.title('Countries with Least Corruption')
plt.xlabel('Country', fontsize=13)
plt.ylabel('Corruption Index', fontsize=13)
plt.xticks(rotation=30, ha='right')
corr_ = country['Trust (Government Corruption)']
coun_ =country['Country']
sns.barplot(x=coun_, y=corr_)
# Out:
# <Axes: title={'center': 'Countries with Least Corruption'}, xlabel='Country', ylabel='Trust (Government Corruption)'>

# %% [markdown]
# It shows that Indonesia has the lowest corruption

# %%
country = df.sort_values(by='Trust (Government Corruption)').tail(10)
plt.rcParams['figure.figsize'] = (10,5)
plt.title('Countries with Most Corruption')
plt.xlabel('Country', fontsize=13)
plt.ylabel('Corruption Index', fontsize=13)
plt.xticks(rotation=30, ha='right')
corr_ = country['Trust (Government Corruption)']
coun_ =country['Country']
sns.barplot(x=coun_, y=corr_)
# Out:
# <Axes: title={'center': 'Countries with Most Corruption'}, xlabel='Country', ylabel='Trust (Government Corruption)'>

# %% [markdown]
# It shows that Rwanda has the highest corruption.

# %%
# corruption vs happiness
plt.rcParams['figure.figsize'] = (10,6)
hap_s = df['Happiness Score']
cor_ = df['Trust (Government Corruption)']
sns.scatterplot(x=hap_s, y=cor_, hue=df.Region, s=100)
plt.legend(loc='upper left', fontsize='8')
plt.xlabel('Happiness Score')
plt.ylabel('Corruption')
plt.show()
